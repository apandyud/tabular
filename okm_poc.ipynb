# %%
import pandas as pd
import numpy as np

okm = pd.read_csv('data/2021_6_tanuloi_small.csv', encoding='UTF-8', sep=';', decimal=',')

# %%
okm
# Out:
#        evfolyam  tipus  valid  megye_kod  regio_kod  teltip  isknagy  fentip  \
# 0             6      1      1         10          6       1        2      73
# 1             6      1      1         13          1       1        3     220
# 2             6      1      1         12          5       3        2      40
# 3             6      1      1         18          2       2        3     220
# 4             6      1      1         15          6       1        2      41
# ...         ...    ...    ...        ...        ...     ...      ...     ...
# 91936         6      1      0          4          5       1        1     220
# 91937         6      1      1          8          6       2        3      40
# 91938         6      1      1         13          1       2        3     220
# 91939         6      1      0         13          1       1        3     220
# 91940         6      1      1          7          3       3        3      40
#
# ...

# %%
okm.columns
# Out:
# Index(['evfolyam', 'tipus', 'valid', 'megye_kod', 'regio_kod', 'teltip',
#        'isknagy', 'fentip', 'M_zpsc', 'M_zpsc_se', 'O_zpsc', 'O_zpsc_se',
#        'm_szint', 'o_szint', 'suly', 'nem', 'csh_index'],
#       dtype='object')

# %%
with open('data/6_evfolyam_tanuloi_beolvaso.sps','r',encoding='cp1250') as f:
    lines = [l.replace('\n','') for l in f.readlines()]

# %%
res = {}
for c in okm.columns:
    res[c] = []
mode = None
for l in lines:
    for c in okm.columns:
        l = l.replace('"','').replace("'","")
        if l.startswith(c):            
            res[c].append(l.replace(c, '').strip())

# %%
pip install Pyreadstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 43.0 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pyreadstat

# %%
#pandas.read_spss('data/2021_6_tanuloi.sav')
#df, meta = pyreadstat.read_sav('file_name.sav', usecols=['var1', 'var2'])

# %%
df, meta = pyreadstat.read_sav('data/2021_6_tanuloi.sav')

# %%
df
# Out:
#        evfolyam  tipus  valid  megye_kod  regio_kod  teltip  isknagy fentip  \
# 0           6.0    1.0    1.0       10.0        6.0     1.0      2.0    073
# 1           6.0    1.0    1.0       13.0        1.0     1.0      3.0    220
# 2           6.0    1.0    1.0       12.0        5.0     3.0      2.0    040
# 3           6.0    1.0    1.0       18.0        2.0     2.0      3.0    220
# 4           6.0    1.0    1.0       15.0        6.0     1.0      2.0    041
# ...         ...    ...    ...        ...        ...     ...      ...    ...
# 91936       6.0    1.0    0.0        4.0        5.0     1.0      1.0    220
# 91937       6.0    1.0    1.0        8.0        6.0     2.0      3.0    040
# 91938       6.0    1.0    1.0       13.0        1.0     2.0      3.0    220
# 91939       6.0    1.0    0.0       13.0        1.0     1.0      3.0    220
# 91940       6.0    1.0    1.0        7.0        3.0     3.0      3.0    040
#
# ...

# %%
meta.value_labels
# Out:
# {'labels0': {6.0: '6. évfolyam', 8.0: '8. évfolyam', 10.0: '10. évfolyam'},
#  'labels1': {1.0: 'általános iskola',
#   2.0: '8 évfolyamos gimnázium',
#   3.0: '6 évfolyamos gimnázium',
#   4.0: '4 évfolyamos gimnázium',
#   5.0: 'technikum',
#   6.0: 'szakképző iskola',
#   7.0: 'szakiskola'},
#  'labels2': {0.0: 'nem számít bele az országosba',
#   1.0: 'beleszámít az országosba',
#   2.0: 'csak matematikából számít bele az országosba'},
#  'labels3': {0.0: 'Budapest',
#   1.0: 'Baranya',
#   2.0: 'Bács-Kiskun',
#   3.0: 'Békés',
#   4.0: 'Borsod-Abaúj-Zemplén',
#   5.0: 'Csongrád-Csanád',
#   6.0: 'Fejér',
#   7.0: 'Győr-Moson-Sopron',
#   8.0: 'Hajdú-Bihar',
#   9.0: 'Heves',
#   10.0: 'Jász-Nagykun-Szolnok',
#   11.0: 'Komárom-Esztergom',
#   12.0: 'Nógrád',
#   13.0: 'Pest',
#   14.0: 'Somogy',
#   15.0: 'Szabolcs-Szatmár-Bereg',
#   16.0: 'Tolna',
#   17.0: 'Vas',
#   18.0: 'Veszprém',
#   19.0: 'Zala'},
#  'labels4': {0.0: 'Budapest',
#   1.0: 'Közép-Magyarország',
# ...

# %%
meta.variable_value_labels
# Out:
# {'evfolyam': {6.0: '6. évfolyam', 8.0: '8. évfolyam', 10.0: '10. évfolyam'},
#  'tipus': {1.0: 'általános iskola',
#   2.0: '8 évfolyamos gimnázium',
#   3.0: '6 évfolyamos gimnázium',
#   4.0: '4 évfolyamos gimnázium',
#   5.0: 'technikum',
#   6.0: 'szakképző iskola',
#   7.0: 'szakiskola'},
#  'valid': {0.0: 'nem számít bele az országosba',
#   1.0: 'beleszámít az országosba',
#   2.0: 'csak matematikából számít bele az országosba'},
#  'megye_kod': {0.0: 'Budapest',
#   1.0: 'Baranya',
#   2.0: 'Bács-Kiskun',
#   3.0: 'Békés',
#   4.0: 'Borsod-Abaúj-Zemplén',
#   5.0: 'Csongrád-Csanád',
#   6.0: 'Fejér',
#   7.0: 'Győr-Moson-Sopron',
#   8.0: 'Hajdú-Bihar',
#   9.0: 'Heves',
#   10.0: 'Jász-Nagykun-Szolnok',
#   11.0: 'Komárom-Esztergom',
#   12.0: 'Nógrád',
#   13.0: 'Pest',
#   14.0: 'Somogy',
#   15.0: 'Szabolcs-Szatmár-Bereg',
#   16.0: 'Tolna',
#   17.0: 'Vas',
#   18.0: 'Veszprém',
#   19.0: 'Zala'},
#  'regio_kod': {0.0: 'Budapest',
#   1.0: 'Közép-Magyarország',
# ...
