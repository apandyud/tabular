# %%
import pandas as pd
import numpy as np

okm = pd.read_csv('data/2021_6_tanuloi.csv', encoding='UTF-8', sep=';', decimal=',')

# %%
okm['csh_index'].hist()
# Out:
# <Axes: >

# %%
okm
# Out:
#        evfolyam  tipus  valid  megye_kod  regio_kod  teltip  isknagy  fentip  \
# 0             6      1      1         10          6       1        2      73
# 1             6      1      1         13          1       1        3     220
# 2             6      1      1         12          5       3        2      40
# 3             6      1      1         18          2       2        3     220
# 4             6      1      1         15          6       1        2      41
# ...         ...    ...    ...        ...        ...     ...      ...     ...
# 91936         6      1      0          4          5       1        1     220
# 91937         6      1      1          8          6       2        3      40
# 91938         6      1      1         13          1       2        3     220
# 91939         6      1      0         13          1       1        3     220
# 91940         6      1      1          7          3       3        3      40
#
#       M_zpsc M_zpsc_se  ...         bs_suly93         bs_suly94  \
# 0       1250        74  ...  1,13333333333333  4,53333333333333
# 1       1575        53  ...                 2                 3
# 2       1425        50  ...  1,17647058823529  1,17647058823529
# 3       1450        57  ...                 0           1,03125
# 4       1800        53  ...  5,14285714285714                 0
# ...      ...       ...  ...               ...               ...
# 91936   1125        87  ...
# 91937   1400        59  ...                 0                 0
# 91938   1325        68  ...  3,20689655172414                 0
# 91939                   ...
# 91940   1850        53  ...  1,04545454545455  3,13636363636364
#
#               bs_suly95         bs_suly96         bs_suly97         bs_suly98  \
# 0      1,13333333333333  2,26666666666667  1,13333333333333                 0
# 1                     1                 2                 0                 2
# 2      1,17647058823529                 0                 0  2,35294117647059
# 3                     0                 0           1,03125           1,03125
# 4                     0  2,57142857142857  1,28571428571429  1,28571428571429
# ...                 ...               ...               ...               ...
# 91936
# 91937                 0  2,10526315789474                 0  2,10526315789474
# 91938  4,27586206896552  2,13793103448276                 0  1,06896551724138
# 91939
# 91940  3,13636363636364  2,09090909090909  1,04545454545455                 0
#
#               bs_suly99        bs_suly100        bs_suly101  halaszt
# 0      1,13333333333333  2,26666666666667                 0
# 1                     1                 1                 0
# 2      2,35294117647059  1,17647058823529  1,17647058823529
# 3                 4,125           1,03125                 0
# 4      1,28571428571429                 0  3,85714285714286
# ...                 ...               ...               ...      ...
# 91936
# 91937  1,05263157894737  1,05263157894737  3,15789473684211
# 91938  1,06896551724138                 0  1,06896551724138
# 91939
# 91940  5,22727272727273  2,09090909090909  1,04545454545455
#
# [91941 rows x 230 columns]

# %%
# !pip install llama-index-core
# !pip install llama-index-llms-openai
# !pip install llama-index-llms-replicate
# !pip install llama-index-embeddings-huggingface
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting llama-index-core
#   Downloading llama_index_core-0.10.44-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (6.0.1)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core)
#   Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting dataclasses-json (from llama-index-core)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (2024.6.0)
# Collecting httpx (from llama-index-core)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting llamaindex-py-client<0.2.0,>=0.1.18 (from llama-index-core)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl.metadata (760 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (3.3)
# Collecting nltk<4.0.0,>=3.8.1 (from llama-index-core)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (1.26.4)
# Collecting openai>=1.1.0 (from llama-index-core)
#   Downloading openai-1.34.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pandas in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (2.32.3)
# Collecting tenacity<9.0.0,>=8.2.0 (from llama-index-core)
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core) (1.16.0)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting pydantic>=1.10 (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core)
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 15.7 MB/s eta 0:00:00
# Collecting anyio (from httpx->llama-index-core)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core) (2024.6.2)
# Collecting httpcore==1.* (from httpx->llama-index-core)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core) (3.7)
# Collecting sniffio (from httpx->llama-index-core)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting click (from nltk<4.0.0,>=3.8.1->llama-index-core)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk<4.0.0,>=3.8.1->llama-index-core)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (2024.5.15)
# Collecting distro<2,>=1.7.0 (from openai>=1.1.0->llama-index-core)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core) (2.2.1)
# Collecting greenlet!=0.4.17 (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from anyio->httpx->llama-index-core) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.0)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core)
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core) (1.16.0)
# Downloading llama_index_core-0.10.44-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 98.3 MB/s eta 0:00:00ta 0:00:01
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 101.8 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 251.3 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 230.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 224.1 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 107.2 MB/s eta 0:00:00
# Downloading openai-1.34.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 258.2 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 101.7 MB/s eta 0:00:00
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 107.9 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 226.4 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 235.0 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 256.5 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 210.2 MB/s eta 0:00:00
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 209.1 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 251.1 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 248.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 102.5 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 253.7 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 232.4 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 251.4 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 229.1 MB/s eta 0:00:00
# Installing collected packages: dirtyjson, tenacity, sniffio, pydantic-core, mypy-extensions, multidict, marshmallow, joblib, h11, greenlet, frozenlist, distro, deprecated, click, attrs, async-timeout, annotated-types, yarl, typing-inspect, tiktoken, SQLAlchemy, pydantic, nltk, httpcore, anyio, aiosignal, httpx, dataclasses-json, aiohttp, openai, llamaindex-py-client, llama-index-core
# Successfully installed SQLAlchemy-2.0.30 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 async-timeout-4.0.3 attrs-23.2.0 click-8.1.7 dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 frozenlist-1.4.1 greenlet-3.0.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 joblib-1.4.2 llama-index-core-0.10.44 llamaindex-py-client-0.1.19 marshmallow-3.21.3 multidict-6.0.5 mypy-extensions-1.0.0 nltk-3.8.1 openai-1.34.0 pydantic-2.7.4 pydantic-core-2.18.4 sniffio-1.3.1 tenacity-8.3.0 tiktoken-0.7.0 typing-inspect-0.9.0 yarl-1.9.4
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting llama-index-llms-openai
#   Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.24 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-llms-openai) (0.10.44)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.6.0)
# Requirement already satisfied: httpx in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.34.0)
# Requirement already satisfied: pandas in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.7.4)
# Requirement already satisfied: anyio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.18.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl (11 kB)
# Installing collected packages: llama-index-llms-openai
# Successfully installed llama-index-llms-openai-0.1.22
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting llama-index-llms-replicate
#   Downloading llama_index_llms_replicate-0.1.3-py3-none-any.whl.metadata (645 bytes)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-llms-replicate) (0.10.44)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2024.6.0)
# Requirement already satisfied: httpx in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.34.0)
# Requirement already satisfied: pandas in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.7.4)
# Requirement already satisfied: anyio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.14.0)
# Requirement already satisfied: click in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (2.18.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-replicate) (1.16.0)
# Downloading llama_index_llms_replicate-0.1.3-py3-none-any.whl (2.9 kB)
# Installing collected packages: llama-index-llms-replicate
# Successfully installed llama-index-llms-replicate-0.1.3
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.2.1-py3-none-any.whl.metadata (725 bytes)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-embeddings-huggingface) (0.10.44)
# Collecting sentence-transformers<3.0.0,>=2.6.1 (from llama-index-embeddings-huggingface)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.6.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.9.5)
# Collecting minijinja>=1.0 (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Downloading minijinja-2.0.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.0.30)
# Requirement already satisfied: dataclasses-json in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.34.0)
# Requirement already satisfied: pandas in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (10.3.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (4.41.2)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (2.3.1)
# Collecting scikit-learn (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.7.4)
# Requirement already satisfied: anyio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: click in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: sympy in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (1.12.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (12.5.40)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.18.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Downloading llama_index_embeddings_huggingface-0.2.1-py3-none-any.whl (7.1 kB)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 22.4 MB/s eta 0:00:00
# Downloading minijinja-2.0.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.2/853.2 kB 58.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 97.4 MB/s eta 0:00:00ta 0:00:01
# Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 94.3 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, minijinja, scikit-learn, sentence-transformers, llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.2.1 minijinja-2.0.1 scikit-learn-1.5.0 scipy-1.13.1 sentence-transformers-2.7.0 threadpoolctl-3.5.0

# %%
pip install langchain
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting langchain
#   Downloading langchain-0.2.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_core-0.2.5-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.77-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (2.7.4)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/arpad_ts/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading langchain-0.2.3-py3-none-any.whl (974 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 37.2 MB/s eta 0:00:00
# Downloading langchain_core-0.2.5-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 245.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.77-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 244.8 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 244.4 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 217.9 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: packaging, orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.3 langchain-core-0.2.5 langchain-text-splitters-0.2.1 langsmith-0.1.77 orjson-3.10.4 packaging-23.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()
# Out:
#  ········

# %%
pip install -qU langchain-mistralai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.environ["MISTRAL_API_KEY"] = 'aSwQOzxOGVmxBUht700jp9cjhC4eR66g'

from langchain_mistralai import ChatMistralAI

model = ChatMistralAI(model="mistral-large-latest")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Hello! In Italian, this is typically translated as "Ciao!" Please note that "Ciao" can be used both for hello and goodbye.', response_metadata={'token_usage': {'prompt_tokens': 15, 'total_tokens': 47, 'completion_tokens': 32}, 'model': 'mistral-large-latest', 'finish_reason': 'stop'}, id='run-4ab757e2-b946-4404-becb-927b076e74d4-0')

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
result = model.invoke(messages)
parser.invoke(result)
# Out:
# 'Hello! In Italian, this is typically translated as "Ciao!" Please note that Italian, like many other languages, has formal and informal ways of greeting, and "Ciao" is an informal greeting. For a more formal greeting, you can use "Salve!" instead.'

# %%
chain = model | parser

# %%
chain.invoke(messages)
# Out:
# 'Hello! In Italian, this is typically translated as "Ciao!" Please note that Italian, like many languages, has formal and informal ways of greeting. "Ciao" is informal and is generally used among friends or people you know well. For a more formal greeting, you might use "Salve!" instead.'

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
system_template = "Translate the following into {language}:"

# %%
prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
result = prompt_template.invoke({"language": "italian", "text": "hi"})

result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following into italian:'), HumanMessage(content='hi')])

# %%
result.to_messages()
# Out:
# [SystemMessage(content='Translate the following into italian:'),
#  HumanMessage(content='hi')]

# %%
chain = prompt_template | model | parser

# %%
chain.invoke({"language": "italian", "text": "hi"})
# Out:
# 'Hello! The translation of "hi" into Italian is "ciao".'

# %%
! pip install langchain_community
